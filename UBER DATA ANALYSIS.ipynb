# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import datetime as dt         # libraby to extract datetime  features

# %%
#LOADING THE DATA(bring it in)
df = pd.read_csv("https://raw.githubusercontent.com/waleolajumoke/uberdataanalysis/main/uber.csv")
df
# Out:
#                  pickup_dt        borough  pickups  spd   vsb  temp  dewp  \
# 0      2015-01-01 01:00:00          Bronx      152  5.0  10.0  30.0   7.0
# 1      2015-01-01 01:00:00       Brooklyn     1519  5.0  10.0  30.0   7.0
# 2      2015-01-01 01:00:00            EWR        0  5.0  10.0  30.0   7.0
# 3      2015-01-01 01:00:00      Manhattan     5258  5.0  10.0  30.0   7.0
# 4      2015-01-01 01:00:00         Queens      405  5.0  10.0  30.0   7.0
# ...                    ...            ...      ...  ...   ...   ...   ...
# 29096  2015-06-30 23:00:00            EWR        0  7.0  10.0  75.0  65.0
# 29097  2015-06-30 23:00:00      Manhattan     3828  7.0  10.0  75.0  65.0
# 29098  2015-06-30 23:00:00         Queens      580  7.0  10.0  75.0  65.0
# 29099  2015-06-30 23:00:00  Staten Island        0  7.0  10.0  75.0  65.0
# 29100  2015-06-30 23:00:00            NaN        3  7.0  10.0  75.0  65.0
#
#           slp  pcp01  pcp06  pcp24   sd hday
# ...

# %%
#DATA OBSERVATION
#Data has been cleaned
#The holiday are in catergorical data
#The weather variables are numerical
#pick-up date has both and time
#Borough contains name of where the pickup is made
#Data starts from Jan 1st 2015 to 30th June 2015(6 months worth of data to analyze)

# %%
df.head()
# Out:
#              pickup_dt    borough  pickups  spd   vsb  temp  dewp     slp  \
# 0  2015-01-01 01:00:00      Bronx      152  5.0  10.0  30.0   7.0  1023.5
# 1  2015-01-01 01:00:00   Brooklyn     1519  5.0  10.0  30.0   7.0  1023.5
# 2  2015-01-01 01:00:00        EWR        0  5.0  10.0  30.0   7.0  1023.5
# 3  2015-01-01 01:00:00  Manhattan     5258  5.0  10.0  30.0   7.0  1023.5
# 4  2015-01-01 01:00:00     Queens      405  5.0  10.0  30.0   7.0  1023.5
#
#    pcp01  pcp06  pcp24   sd hday
# 0    0.0    0.0    0.0  0.0    Y
# 1    0.0    0.0    0.0  0.0    Y
# 2    0.0    0.0    0.0  0.0    Y
# 3    0.0    0.0    0.0  0.0    Y
# 4    0.0    0.0    0.0  0.0    Y

# %%
df.tail()
# Out:
#                  pickup_dt        borough  pickups  spd   vsb  temp  dewp  \
# 29096  2015-06-30 23:00:00            EWR        0  7.0  10.0  75.0  65.0
# 29097  2015-06-30 23:00:00      Manhattan     3828  7.0  10.0  75.0  65.0
# 29098  2015-06-30 23:00:00         Queens      580  7.0  10.0  75.0  65.0
# 29099  2015-06-30 23:00:00  Staten Island        0  7.0  10.0  75.0  65.0
# 29100  2015-06-30 23:00:00            NaN        3  7.0  10.0  75.0  65.0
#
#           slp  pcp01  pcp06  pcp24   sd hday
# 29096  1011.8    0.0    0.0    0.0  0.0    N
# 29097  1011.8    0.0    0.0    0.0  0.0    N
# 29098  1011.8    0.0    0.0    0.0  0.0    N
# 29099  1011.8    0.0    0.0    0.0  0.0    N
# 29100  1011.8    0.0    0.0    0.0  0.0    N

# %%
df.shape        #To know d number of rows and columns
# Out:
# (29101, 13)

# %%
df.info()       #checking data types, missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29101 entries, 0 to 29100
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pickup_dt  29101 non-null  object
#  1   borough    26058 non-null  object
#  2   pickups    29101 non-null  int64
#  3   spd        29101 non-null  float64
#  4   vsb        29101 non-null  float64
#  5   temp       29101 non-null  float64
#  6   dewp       29101 non-null  float64
#  7   slp        29101 non-null  float64
#  8   pcp01      29101 non-null  float64
#  9   pcp06      29101 non-null  float64
#  10  pcp24      29101 non-null  float64
#  11  sd         29101 non-null  float64
#  12  hday       29101 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 2.9+ MB

# %%
df.isnull().sum()       #How to check for missing data
# Out:
# pickup_dt       0
# borough      3043
# pickups         0
# spd             0
# vsb             0
# temp            0
# dewp            0
# slp             0
# pcp01           0
# pcp06           0
# pcp24           0
# sd              0
# hday            0
# dtype: int64

# %%
df.describe()
# Out:
#             pickups           spd           vsb          temp          dewp  \
# count  29101.000000  29101.000000  29101.000000  29101.000000  29101.000000
# mean     490.215903      5.984924      8.818125     47.669042     30.823065
# std      995.649536      3.699007      2.442897     19.814969     21.283444
# min        0.000000      0.000000      0.000000      2.000000    -16.000000
# 25%        1.000000      3.000000      9.100000     32.000000     14.000000
# 50%       54.000000      6.000000     10.000000     46.000000     30.000000
# 75%      449.000000      8.000000     10.000000     64.500000     50.000000
# max     7883.000000     21.000000     10.000000     89.000000     73.000000
#
#                 slp         pcp01         pcp06         pcp24            sd
# count  29101.000000  29101.000000  29101.000000  29101.000000  29101.000000
# mean    1017.817938      0.003830      0.026129      0.090464      2.529169
# ...

# %%
df.describe(exclude="number")
# Out:
#                   pickup_dt borough   hday
# count                 29101   26058  29101
# unique                 4343       6      2
# top     2015-01-01 01:00:00   Bronx      N
# freq                      7    4343  27980

# %%
#CHECKING UNIQUE VALUES
df["hday"].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
#CHECKING FOR CITIES
df["borough"].unique()
# Out:
# array(['Bronx', 'Brooklyn', 'EWR', 'Manhattan', 'Queens', 'Staten Island',
#        nan], dtype=object)

# %%
#CHECKING D NUMB OF UNIQUE VALUES FOR EACH LOCATION
df["borough"].value_counts()
# Out:
# borough
# Bronx            4343
# Brooklyn         4343
# EWR              4343
# Manhattan        4343
# Queens           4343
# Staten Island    4343
# Name: count, dtype: int64

# %%
#CHECKING TRIP DURING HOLIDAY VS NON HOLIDAY
df["hday"].value_counts()
# Out:
# hday
# N    27980
# Y     1121
# Name: count, dtype: int64

# %%
#CONVERTING PICKUP DATE TO DATETIME USING PANDAS
df["pickup_dt"]=pd.to_datetime(df["pickup_dt"])
df["pickup_dt"]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29101 entries, 0 to 29100
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pickup_dt  29101 non-null  datetime64[ns]
#  1   borough    26058 non-null  object
#  2   pickups    29101 non-null  int64
#  3   spd        29101 non-null  float64
#  4   vsb        29101 non-null  float64
#  5   temp       29101 non-null  float64
#  6   dewp       29101 non-null  float64
#  7   slp        29101 non-null  float64
#  8   pcp01      29101 non-null  float64
#  9   pcp06      29101 non-null  float64
#  10  pcp24      29101 non-null  float64
#  11  sd         29101 non-null  float64
#  12  hday       29101 non-null  object
# dtypes: datetime64[ns](1), float64(9), int64(1), object(2)
# memory usage: 2.9+ MB

# %%
#CONVERSION
df.pickup_dt = pd.to_datetime(df.pickup_dt)

#(EXTRACTING MONTH,DAY)
df.pickup_dt = pd.to_datetime(df.pickup_dt)
df["day_name"] = df.pickup_dt.dt.day_name()
df["month_name"] = df.pickup_dt.dt.month_name()
df["start_hour"] = df.pickup_dt.dt.hour
df["day"] = df.pickup_dt.dt.day
df["year"] = df.pickup_dt.dt.year

# %%
df
# Out:
#                 pickup_dt        borough  pickups  spd   vsb  temp  dewp  \
# 0     2015-01-01 01:00:00          Bronx      152  5.0  10.0  30.0   7.0
# 1     2015-01-01 01:00:00       Brooklyn     1519  5.0  10.0  30.0   7.0
# 2     2015-01-01 01:00:00            EWR        0  5.0  10.0  30.0   7.0
# 3     2015-01-01 01:00:00      Manhattan     5258  5.0  10.0  30.0   7.0
# 4     2015-01-01 01:00:00         Queens      405  5.0  10.0  30.0   7.0
# ...                   ...            ...      ...  ...   ...   ...   ...
# 29096 2015-06-30 23:00:00            EWR        0  7.0  10.0  75.0  65.0
# 29097 2015-06-30 23:00:00      Manhattan     3828  7.0  10.0  75.0  65.0
# 29098 2015-06-30 23:00:00         Queens      580  7.0  10.0  75.0  65.0
# 29099 2015-06-30 23:00:00  Staten Island        0  7.0  10.0  75.0  65.0
# 29100 2015-06-30 23:00:00            NaN        3  7.0  10.0  75.0  65.0
#
#           slp  pcp01  pcp06  pcp24   sd hday  day_name month_name  start_hour  \
# ...

# %%
## removing pickup date column
# df = df.drop("pickup_dt", axis=1)

df
# Out:
#              borough  pickups  spd   vsb  temp  dewp     slp  pcp01  pcp06  \
# 0              Bronx      152  5.0  10.0  30.0   7.0  1023.5    0.0    0.0
# 1           Brooklyn     1519  5.0  10.0  30.0   7.0  1023.5    0.0    0.0
# 2                EWR        0  5.0  10.0  30.0   7.0  1023.5    0.0    0.0
# 3          Manhattan     5258  5.0  10.0  30.0   7.0  1023.5    0.0    0.0
# 4             Queens      405  5.0  10.0  30.0   7.0  1023.5    0.0    0.0
# ...              ...      ...  ...   ...   ...   ...     ...    ...    ...
# 29096            EWR        0  7.0  10.0  75.0  65.0  1011.8    0.0    0.0
# 29097      Manhattan     3828  7.0  10.0  75.0  65.0  1011.8    0.0    0.0
# 29098         Queens      580  7.0  10.0  75.0  65.0  1011.8    0.0    0.0
# 29099  Staten Island        0  7.0  10.0  75.0  65.0  1011.8    0.0    0.0
# 29100            NaN        3  7.0  10.0  75.0  65.0  1011.8    0.0    0.0
#
#        pcp24   sd hday  day_name month_name  start_hour  day  year
# ...

# %%
df.head()
# Out:
#      borough  pickups  spd   vsb  temp  dewp     slp  pcp01  pcp06  pcp24  \
# 0      Bronx      152  5.0  10.0  30.0   7.0  1023.5    0.0    0.0    0.0
# 1   Brooklyn     1519  5.0  10.0  30.0   7.0  1023.5    0.0    0.0    0.0
# 2        EWR        0  5.0  10.0  30.0   7.0  1023.5    0.0    0.0    0.0
# 3  Manhattan     5258  5.0  10.0  30.0   7.0  1023.5    0.0    0.0    0.0
# 4     Queens      405  5.0  10.0  30.0   7.0  1023.5    0.0    0.0    0.0
#
#     sd hday  day_name month_name  start_hour  day  year
# 0  0.0    Y  Thursday    January           1    1  2015
# 1  0.0    Y  Thursday    January           1    1  2015
# 2  0.0    Y  Thursday    January           1    1  2015
# 3  0.0    Y  Thursday    January           1    1  2015
# 4  0.0    Y  Thursday    January           1    1  2015

# %%
#HANDLING MISSING DATA IN BOROUGH
df["borough"].value_counts(normalize=True,dropna=False)
# Out:
# borough
# Bronx            0.149239
# Brooklyn         0.149239
# EWR              0.149239
# Manhattan        0.149239
# Queens           0.149239
# Staten Island    0.149239
# NaN              0.104567
# Name: proportion, dtype: float64

# %%
#OBSERVATION
1.The borough have same numbers of values
2.The missing values is closeto each value under borough

# %%
#CHANGE MISSING VALUES TO UNKNOWN
df["borough"] = df["borough"].fillna("Unknown")

# %%
df["borough"].value_counts()
# Out:
# borough
# Bronx            4343
# Brooklyn         4343
# EWR              4343
# Manhattan        4343
# Queens           4343
# Staten Island    4343
# Unknown          3043
# Name: count, dtype: int64

# %%
#CHECK MISSING VALUES
df.isnull().sum()
# Out:
# borough       0
# pickups       0
# spd           0
# vsb           0
# temp          0
# dewp          0
# slp           0
# pcp01         0
# pcp06         0
# pcp24         0
# sd            0
# hday          0
# day_name      0
# month_name    0
# start_hour    0
# day           0
# year          0
# dtype: int64

# %%
 #COUNTING TOTLA OF TRIP ON HOLIDAY VS NON HOLIDAY
holiday = df["hday"].value_counts()
holiday
# Out:
# hday
# N    27980
# Y     1121
# Name: count, dtype: int64

# %%
sns.countplot(x="hday", data=df)
#UNIVARIATE ANALYSIS
# plotting trip on holiday vs non holiday
# univariate analysis
sns.countplot(df, x="hday")

#ADDING LABELS AND TITTLE
# Out:
# <Axes: xlabel='hday', ylabel='count'>

# %%
#MULTIVARIATE ANALYSIS
num_var = ['pickups', 'spd', 'vsb', 'temp', 'dewp', 'slp', 'pcp01', 'pcp06', 'pcp24', 'sd']
corr= df[num_var].corr()
corr
# Out:
#           pickups       spd       vsb      temp      dewp       slp     pcp01  \
# pickups  1.000000  0.011103 -0.007484  0.054857  0.033456 -0.015011  0.004406
# spd      0.011103  1.000000  0.089056 -0.294548 -0.321730 -0.091698 -0.000250
# vsb     -0.007484  0.089056  1.000000  0.023981 -0.232188  0.165451 -0.487121
# temp     0.054857 -0.294548  0.023981  1.000000  0.896665 -0.224439 -0.012767
# dewp     0.033456 -0.321730 -0.232188  0.896665  1.000000 -0.310104  0.115585
# slp     -0.015011 -0.091698  0.165451 -0.224439 -0.310104  1.000000 -0.088466
# pcp01    0.004406 -0.000250 -0.487121 -0.012767  0.115585 -0.088466  1.000000
# pcp06   -0.002909  0.016266 -0.117681 -0.037722  0.012435 -0.103059  0.126185
# pcp24   -0.020219 -0.010563  0.000323 -0.014382  0.001250 -0.133964  0.001017
# sd      -0.008241  0.097919 -0.048110 -0.548750 -0.492485  0.123538 -0.000974
#
#             pcp06     pcp24        sd
# pickups -0.002909 -0.020219 -0.008241
# ...

# %%
#OBSERVATION
1.Weather variables doesnt affect pickup

# %%
sns.heatmap(corr,annot=True, fmt = ".1f")    #ANNOTATE MEANS TO INSERT D VALUES IN THE BOXES
# Out:
# <Axes: >

# %%
#PICKUP ACCROSS THE MONTH

# months = df.month_name.unique().tolist()
# month_trend = pd.Categorical(df.month_name, ordered=True, categories=months)

plt.figure(figsize=(20,7))
sns.lineplot(df, x="month_name", y="pickups", color="red", ci=0)
plt.ylabel('Total pickups')
plt.xlabel('Month')
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(df, x="day_name", y="pickups", color="red", ci=0)
plt.ylabel('Total pickups')
plt.xlabel('day of Month')
plt.show()

# %%
#PICK UP HOUR OF THE DAY IN DIFFERENT BOROUGH
plt.figure(figsize=(20,7))
sns.lineplot(df, x="start_hour", y="pickups", color="red", ci=0, hue="borough")
plt.ylabel('Total pickups')
plt.xlabel('Hour of the day')
plt.show()

# %%
#OBSERVATION
